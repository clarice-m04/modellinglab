# %% [markdown]
# # Project 2
# **Group B** \
# Students: Elodie-Angélique Lendi, Mridhula Jayasankar, Clarice Jasmine Mihalache

# %% [markdown]
# ### Question 3
# The Henry coefficient of $CH_4$ was found to be: 0.000001 $\frac{mol}{kg.Pa}$ and that of $CO_2$ was found to be: 0.000005 $\frac{mol}{kg.Pa}$. \
# The Henry Law is defined as:
#
# $$\ C = H \times P $$
#
# where:
# - $C$ is the concentration of the dissolved gas in the liquid $[\text{mol}/\text{kg}]$,
# - $P$ is the partial pressure of the gas $[\text{Pa}]$,
# - $H$ is the Henry's law constant $[\frac{mol}{kg.Pa}]$.
#
# Firstly this means that for the same partial pressure  $P$, the gas with the larger Henry's constant $H$ will have a higher solubility in the liquid.\
#
# Comparing the values:
#    $
#    H_{CO_2} = 0.000005 > H_{CH_4} = 0.000001
#    $
#    This means that at identical conditions, CO₂ is 5 times more soluble than CH₄.
#
# Physically, this aligns with molecular properties:
#    - CO₂ is more soluble because it interacts more strongly with water due to its polarity and ability to form weak intermolecular interactions.
#    - CH₄ is a nonpolar, hydrophobic gas, leading to much lower solubility.
#
#
# This implies that in processes like gas absorption or environmental studies, CO₂ will dissolve more readily in water than CH₄ under the same pressure and temperature conditions.
# So the larger the Henry coefficient the more soluble the gas is in the liquid for the same partial pressure.

# %% [markdown]
# ### Question 4

# %%
import matplotlib.pyplot as plt

# %%
#Data

Pressure = [0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0, 5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2]

CH4_IRMOF_data = [0.02266292256712, 0.08756719507668, 0.1564975455208, 0.22497333877876, 0.28796197743236, 0.357963784101, 0.42640710898852, 0.4826423265906, 0.56394312617236, 0.62884739868192, 0.68323191916892, 0.76573404845696, 0.816579516566, 0.90476361068104, 0.95077129159452, 1.0297343685046, 1.1027232652537, 1.122074414036]

CH4_IRMOF_error = [0.0031452450876092, 0.0064369312111919, 0.0117282297867, 0.013877940203396, 0.020700871555393, 0.010644476832477, 0.01996696551994, 0.014097406013668, 0.021575616940038, 0.018106291799972, 0.017374188781832, 0.064649866057249, 0.033159093283021, 0.057892260823065, 0.048823015863099, 0.019482104515958, 0.035450702930159, 0.039379408692561]

CO2_IRMOF_data = [0.10091169532752, 0.39653620818372, 0.71810294902148, 1.0437607045347, 1.3820811245195, 1.7378045910601, 2.164016889826, 2.4447384206502, 2.7972799868878, 3.2244988051373, 3.505772298259, 3.9983499462042, 4.490375631852, 4.9640566882012, 5.356761628673, 6.1225281455004, 6.7894609427084, 7.1418726354642]

CO2_IRMOF_error = [0.0044829872918165, 0.026518212343828, 0.046020682466568, 0.068782263765025, 0.094414671623849, 0.083561399532469, 0.1136161024836, 0.08899660294213, 0.1982451166317, 0.10884308243038, 0.31872610198832, 0.17102670904128, 0.36444411626998, 0.35617340057177, 0.33915667158376, 0.4907282182817, 0.45901632064464, 0.56618565198776]

#Plotting

plt.figure(figsize=(10, 6))  
plt.title("Isotherms of CO2 and CH4 at 300K", fontname='Times New Roman', fontsize=14)
plt.xlabel("Pressure [bar]", fontname='Times New Roman', fontsize=12)
plt.ylabel("Adsorbent amount [mol/kg]", fontname='Times New Roman', fontsize=12)
plt.errorbar(Pressure, CH4_IRMOF_data, yerr=CH4_IRMOF_error, fmt='o', color='#58b3fc', ecolor='#58b3fc', elinewidth=3, capsize=4)
plt.errorbar(Pressure, CO2_IRMOF_data, yerr=CO2_IRMOF_error, fmt='o', color='#f44242', ecolor='#f44242', elinewidth=3, capsize=4)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# The adsorption behavior of CH₄ and CO₂ in IRMOF-1 as a function of pressure reveals a consistent difference between the adsorption of the two gases. At low pressures, CH₄ exhibits only very small interactions with the adsorbent, as indicated by the near-zero uptake in the initial region of the isotherm. This suggests that the affinity of IRMOF-1 for CH₄ is weak, with only minimal adsorption sites being occupied until the pressure becomes sufficiently large to drive more molecules into the pores. As the pressure increases, CH₄ adsorption rises gradually, but even at the highest measured pressure of 10.2 bar, the total uptake remains below 1.2 mol/kg, indicating overall low capacity and weak adsorbate–adsorbent interactions.
#
# In contrast, CO₂ shows a much steeper rise in uptake even at low pressures, reflecting strong interactions between the CO₂ molecules and the IRMOF-1 framework. This difference arises because CO₂ possesses a significant quadrupole moment and is more polarizable than CH₄, enabling stronger electrostatic and van der Waals interactions with the adsorbent's metal centers and organic linkers. As a result, the initial slope of the CO₂ isotherm is much higher, implying a greater affinity and heat of adsorption compared to CH₄.
#
# As pressure increases beyond the low-pressure regime, CO₂ adsorption continues to rise sharply and reaches values exceeding 7 mol/kg at 10.2 bar, far surpassing CH₄ under the same conditions. This behavior demonstrates that not only are the binding interactions stronger for CO₂, but the available pore volume of IRMOF-1 is utilized much more effectively by CO₂ molecules. The smaller kinetic diameter of CO₂ compared to CH₄ further improves its ability to access adsorption sites within the micropores of the framework.
#
# Overall, the data clearly shows that CH₄ adsorption in IRMOF-1 is limited both by weak interactions at low pressure and by low capacity at high pressure, whereas CO₂ exhibits strong adsorption from the get go and rapidly saturates the material at much higher uptake levels. This makes IRMOF-1 far more suitable for CO₂ capture applications, while CH₄ uptake remains comparatively very low across the entire pressure range.
