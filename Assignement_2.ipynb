# %%
# Import of package "
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# data set #

Pressure = [0.2, 0.8, 1.4, 2.0, 2.6, 3.2, 3.8, 4.4, 5.0, 5.6, 6.2, 6.8, 7.4, 8.0, 8.6, 9.2, 9.8, 10.2]

CH4_IRMOF_data =  [0.02204602352876, 0.08948282893264, 0.156659887373, 0.2259798582624, 0.29364394225936, 0.3542299215004, 0.42738116010172, 0.4889736588264, 
                   0.54975444829008, 0.62446416867252, 0.68992040347956, 0.76411062993496, 0.83417737334448, 0.91291317166148, 0.97473294897924, 1.0201237308544, 
                   1.0867488269972, 1.1612962055275]

CO2_IRMOF_data =  [0.09522973050052, 0.40429614871888, 0.7407658715886, 1.0694756539232, 1.3851331513408, 1.7288757891891, 2.1050218607365, 2.4166857485901, 
                   2.8385148173466, 3.1830691644558, 3.5800923981962, 4.0875405598029, 4.5669360493495, 5.0027589857656, 5.6306648017048, 6.1650617107768, 
                   6.6152681352978, 6.830241215981]

# plot the graph #

plt.scatter(Pressure, CO2_IRMOF_data, label = "CO2", color="red")
plt.scatter(Pressure, CH4_IRMOF_data, label = "CH4", color="blue")
plt.legend()
plt.title("Isotherms of CH4 and C02 at 300K")
plt.xlabel("Pressure (bar)")
plt.ylabel("Loading (mol/kg)")
